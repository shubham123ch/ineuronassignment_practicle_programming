# %% [markdown]
# # Shubham Kumar Chaturvedi(python practicle programming assigment no: 4)

# %%
#1. Write a Python Program to Find the Factorial of a Number?

# using recursion

def factorial(x):

    if x == 1:
        return 1
    elif x == 0:
        return 1
    elif x < 1:
        return("...sorry,factorial of negative number does not exits ")
    else:
        # recursive call to the function
        return (x * factorial(x-1))


# change the value for a different result
#num = 7

# to take input from the user
num = int(input("Enter a number: "))

# call the factorial function
result = factorial(num)
print("The factorial of", num, "is", result)
# Out:
# Enter a number: -4
# The factorial of -4 is ...sorry,factorial of negative number does not exits

# %%
#2 Write a Python Program to Display the multiplication Table?

num = int(input("enter the number:"))

# To take input from the user
# num = int(input("Display multiplication table of? "))

# Iterate 10 times from i = 1 to 10
for i in range(1, 11):
   print(num, 'x', i, '=', num*i)
# Out:
# enter the number:23
# 23 x 1 = 23
# 23 x 2 = 46
# 23 x 3 = 69
# 23 x 4 = 92
# 23 x 5 = 115
# 23 x 6 = 138
# 23 x 7 = 161
# 23 x 8 = 184
# 23 x 9 = 207
# 23 x 10 = 230

# %%
# Q3. Write a Python Program to Print the Fibonacci sequence?
nterms = int(input ("How many terms the user wants to print? "))  
  
# First two terms  
n1 = 0  
n2 = 1  
count = 0  
  
# Now, we will check if the number of terms is valid or not  
if nterms <= 0:  
    print ("Please enter a positive integer, the given number is not valid")  
# if there is only one term, it will return n_1  
elif nterms == 1:  
    print ("The Fibonacci sequence of the numbers up to", nterms, ": ")  
    print(n1)  
# Then we will generate Fibonacci sequence of number  
else:  
    print ("The fibonacci sequence of the numbers is:")  
    while count < nterms:  
        print(n1)  
        nth = n1 + n2  
       # At last, we will update values  
        n1 = n2  
        n2 = nth  
        count += 1
# Out:
# How many terms the user wants to print? 5
# The fibonacci sequence of the numbers is:
# 0
# 1
# 1
# 2
# 3

# %%
# Q4. Python program to check if the number is an Armstrong number or not

# take input from the user
num = int(input("Enter a number: "))

# initialize sum
sum = 0

# find the sum of the cube of each digit
temp = num
while temp > 0:
   digit = temp % 10
   sum += digit ** 3
   temp //= 10

# display the result
if num == sum:
   print(num,"is an Armstrong number")
else:
   print(num,"is not an Armstrong number")
# Out:
# Enter a number: 153
# 153 is an Armstrong number

# %%
# Q5.Write a Python Program to Find Armstrong Number in an Interval?
# Program to check Armstrong numbers in a certain interval

#lower = 100
lower = int(input("enter lower number:"))
#upper = 2000
upper = int(input("enter upper number:"))


for num in range(lower, upper + 1):


   # order of number
  order = len(str(num))
    
   # initialize sum
  sum = 0

  temp = num
  while temp > 0:
      digit = temp % 10
      sum += digit ** order
      temp //= 10

  if num == sum:
      print(num)
# Out:
# enter lower number:100
# enter upper number:2000
# 153
# 370
# 371
# 407
# 1634

# %%
#Q6. Write a Python Program to Find the Sum of Natural Numbers?
# Sum of natural numbers up to num

#num = 16
num = int(input("enter the number:"))
if num < 0:
   print("Enter a positive number")
else:
   sum = 0
   # use while loop to iterate until zero
   while(num > 0):
       sum += num
       num -= 1
   print("The sum is", sum)
# Out:
# enter the number:4
# The sum is 10
